# %% [markdown]
# # Q1. Write a python program to display all the header tags from wikipedia.org.

# %% [markdown]
# Answer :

# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\admin\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests) (1.26.7)

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
header=[]
for i in soup.find_all('span',class_="mw-headline"):
    header.append(i.text)
import pandas as pd
df=pd.DataFrame({'Header Tags':header})
df
# Out:
#                      Header Tags
# 0           Welcome to Wikipedia
# 1  From today's featured article
# 2               Did you know ...
# 3                    In the news
# 4                    On this day
# 5     From today's featured list
# 6       Today's featured picture
# 7       Other areas of Wikipedia
# 8    Wikipedia's sister projects
# 9            Wikipedia languages

# %% [markdown]
# # Q2.   Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release) and make data frame.

# %% [markdown]
# Answer :

# %%
from bs4 import BeautifulSoup
import requests
imdb_movies=requests.get('https://www.imdb.com/list/ls055592025/?sort=user_rating,desc&st_dt=&mode=detail&page=1')
imdb_movies
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(imdb_movies.content)
data=soup.find_all('h3',class_="lister-item-header")
movies_name=[]
for i in data:
    for j in i.find_all('a'):
        movies_name.append(j.text)
rating=[]
for j in soup.find_all('div',class_="ipl-rating-star small"):
    rating.append(j.text.replace('\n',''))
yor=[]
for k in soup.find_all('span',class_="lister-item-year text-muted unbold"):
    yor.append(k.text.replace('(','').replace(')',''))
import pandas as pd
import numpy as np
df=pd.DataFrame({'Name':movies_name,'Rating':rating,'Year of Release':yor})
print("IMDB’s Top rated 100 movies’ data")
df.index = np.arange(1,len(df)+1)
df
# Out:
# IMDB’s Top rated 100 movies’ data
#                                               Name Rating Year of Release
# 1                         The Shawshank Redemption    9.3            1994
# 2                                    The Godfather    9.2            1972
# 3                                 Schindler's List      9            1993
# 4                            The Godfather Part II      9            1974
# 5    The Lord of the Rings: The Return of the King      9            2003
# ..                                             ...    ...             ...
# 96                           From Here to Eternity    7.6            1953
# 97                               Wuthering Heights    7.5            1939
# 98                               American Graffiti    7.4            1973
# 99                             Terms of Endearment    7.4            1983
# 100                           An American in Paris    7.2            1951
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q3. Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of release) and make data frame.

# %% [markdown]
# Answer :

# %%
from bs4 import BeautifulSoup
import requests
ind_movies=requests.get('https://www.imdb.com/india/top-rated-indian-movies/')
ind_movies
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(ind_movies.content)
d1=soup.find_all('td',class_="titleColumn")
movies_name=[]
for i in d1:
    for j in i.find_all('a'):
        movies_name.append(j.text)
rating=[]
for j in soup.find_all('td',class_="ratingColumn imdbRating"):
    rating.append(j.text.replace('\n',''))
yor=[]
for k in soup.find_all('span',class_="secondaryInfo"):
    yor.append(k.text.replace('(','').replace(')',''))
import pandas as pd
import numpy as np
data=pd.DataFrame({'Name':movies_name,'Rating':rating,'Year of Release':yor})
print("IMDB’s Top rated 100 Indian movies’ data")
df.index = np.arange(1,len(df)+1)
df.head(100)
# Out:
# IMDB’s Top rated 100 Indian movies’ data
#                                               Name Rating Year of Release
# 1                         The Shawshank Redemption    9.3            1994
# 2                                    The Godfather    9.2            1972
# 3                                 Schindler's List      9            1993
# 4                            The Godfather Part II      9            1974
# 5    The Lord of the Rings: The Return of the King      9            2003
# ..                                             ...    ...             ...
# 96                           From Here to Eternity    7.6            1953
# 97                               Wuthering Heights    7.5            1939
# 98                               American Graffiti    7.4            1973
# 99                             Terms of Endearment    7.4            1983
# 100                           An American in Paris    7.2            1951
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q4. Write s python program to display list of respected former presidents of India(i.e. Name , Term of office) from https://presidentofindia.nic.in/former-presidents.htm

# %% [markdown]
# Answer :

# %%
from bs4 import BeautifulSoup
import requests
indian_president=requests.get('https://presidentofindia.nic.in/former-presidents.htm')
indian_president
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(indian_president.content)
pres=soup.find_all('div',class_="presidentListing")
name=[]
for i in pres:
    for j in i.find_all('h3'):
        name.append(j.text.replace('\n',''))
term=[]
for a in pres:
    for b in a.find_all('p'):
        term.append(b.text)
del term[1:9:2]
import pandas as pd
df= pd.DataFrame({'Name':name, 'Term of Office':term})
df1=df.set_index('Name')
df1
# Out:
#                                                                                 Term of Office
# Name
# Shri Ram Nath Kovind (birth - 1945)            Term of Office: 25 July, 2017 to 25 July, 2022
# Shri Pranab Mukherjee (1935-2020)              Term of Office: 25 July, 2012 to 25 July, 2017
# Smt Pratibha Devisingh Patil (birth - 1934)    Term of Office: 25 July, 2007 to 25 July, 2012
# DR. A.P.J. Abdul Kalam (1931-2015)             Term of Office: 25 July, 2002 to 25 July, 2007
# Shri K. R. Narayanan (1920 - 2005)             Term of Office: 25 July, 1997 to 25 July, 2002
# Dr Shankar Dayal Sharma (1918-1999)            Term of Office: 25 July, 1992 to 25 July, 1997
# Shri R Venkataraman (1910-2009)                Term of Office: 25 July, 1987 to 25 July, 1992
# Giani Zail Singh (1916-1994)                   Term of Office: 25 July, 1982 to 25 July, 1987
# Shri Neelam Sanjiva Reddy (1913-1996)          Term of Office: 25 July, 1977 to 25 July, 1982
# Dr. Fakhruddin Ali Ahmed (1905-1977)         Term of Office: 24 August, 1974 to 11 February...
# Shri Varahagiri Venkata Giri (1894-1980)     Term of Office: 3 May, 1969 to 20 July, 1969 a...
# Dr. Zakir Husain (1897-1969)                       Term of Office: 13 May, 1967 to 3 May, 1969
# Dr. Sarvepalli Radhakrishnan (1888-1975)          Term of Office: 13 May, 1962 to 13 May, 1967
# Dr. Rajendra Prasad (1884-1963)               Term of Office: 26 January, 1950 to 13 May, 1962

# %% [markdown]
# # Q5. Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#
# b) Top 10 ODI Batsmen along with the records of their team and rating.
#
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %% [markdown]
# Answer :

# %%
from bs4 import BeautifulSoup
import requests
cricket=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
cricket
# Out:
# <Response [200]>

# %% [markdown]
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#
# Answer :

# %%
soup=BeautifulSoup(cricket.content)
team=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    team.append(i.text)
m1=[]
for j in soup.find_all('td',class_="rankings-block__banner--matches"):
    m1.append(j.text)
m2=[]
for k in soup.find_all('td',class_="table-body__cell u-center-text"):
    m2.append(k.text)
del m2[1:39:2]
matches=m1+m2
p1=[]
for l in soup.find_all('td',class_="rankings-block__banner--points"):
    p1.append(l.text)
p2=[]
for m in soup.find_all('td',class_="table-body__cell u-center-text"):
    p2.append(m.text)
del p2[0:39:2]
points=p1+p2
r1=[]
for n in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    r1.append(n.text.replace('\n',''))
r2=[]
for o in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    r2.append(o.text)
rating=r1+r2
import pandas as pd
import numpy as np
df=pd.DataFrame({'Team':team,'Matches':matches,'Points':points,'Rating':rating})
print('Top 10 ODI teams in men’s cricket :')
df.index = np.arange(1,len(df)+1)
df.head(10)
# Out:
# Top 10 ODI teams in men’s cricket :
#             Team Matches Points  \
# 1    New Zealand      16  2,051
# 2        England      27  3,226
# 3          India      28  3,085
# 4       Pakistan      19  2,005
# 5      Australia      23  2,325
# 6   South Africa      21  2,111
# 7     Bangladesh      27  2,639
# 8      Sri Lanka      29  2,658
# 9    West Indies      38  2,621
# 10   Afghanistan      18  1,238
#
#                                                Rating
# 1                               128               ...
# 2                                                 119
# 3                                                 110
# 4                                                 106
# 5                                                 101
# 6                                                 101
# 7                                                  98
# 8                                                  92
# 9                                                  69
# 10                                                 69

# %% [markdown]
# b) Top 10 ODI Batsmen along with the records of their team and rating.
#
# Answer :

# %%
batsmen=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
batsmen
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(batsmen.content)
p1=[]
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    p1.append(i.text)
p2=[]
for j in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    p2.append(j.text.replace('\n',''))
player=p1+p2
t1=[]
for a in soup.find_all('div',class_="rankings-block__banner--nationality"):
    t1.append(a.text.replace('\n',''))
t2=[]
for b in soup.find_all('span',class_="table-body__logo-text"):
    t2.append(b.text)
team=t1+t2
r1=[]
for n in soup.find_all('div',class_="rankings-block__banner--rating"):
    r1.append(n.text)
r2=[]
for o in soup.find_all('td',class_="table-body__cell rating"):
    r2.append(o.text)
rating=r1+r2
import pandas as pd
import numpy as np
df=pd.DataFrame({'Batsmen':player,'Team':team,'Rating':rating})
print('Top 10 ODI Batsmen :')
df.index = np.arange(1,len(df)+1)
df.head(10)
# Out:
# Top 10 ODI Batsmen :
#                   Batsmen                     Team Rating
# 1              Babar Azam  PAK                        892
# 2             Imam-ul-Haq                      PAK    815
# 3   Rassie van der Dussen                       SA    789
# 4         Quinton de Kock                       SA    784
# 5             Virat Kohli                      IND    767
# 6            Rohit Sharma                      IND    763
# 7             Ross Taylor                       NZ    744
# 8            David Warner                      AUS    737
# 9          Jonny Bairstow                      ENG    732
# 10            Aaron Finch                      AUS    715

# %% [markdown]
# c) Top 10 ODI bowlers along with the records of their team and rating.
#
# Answer :

# %%
bowlers=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
bowlers
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(bowlers.content)
p1=[]
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    p1.append(i.text)
p2=[]
for j in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    p2.append(j.text.replace('\n',''))
player=p1+p2
t1=[]
for a in soup.find_all('div',class_="rankings-block__banner--nationality"):
    t1.append(a.text.replace('\n',''))
t2=[]
for b in soup.find_all('span',class_="table-body__logo-text"):
    t2.append(b.text)
team=t1+t2
r1=[]
for n in soup.find_all('div',class_="rankings-block__banner--rating"):
    r1.append(n.text)
r2=[]
for o in soup.find_all('td',class_="table-body__cell rating"):
    r2.append(o.text)
rating=r1+r2
import pandas as pd
import numpy as np
df=pd.DataFrame({'Bowlers':player,'Team':team,'Rating':rating})
print('Top 10 ODI Bowlers :')
df.index = np.arange(1,len(df)+1)
df.head(10)
# Out:
# Top 10 ODI Bowlers :
#              Bowlers                    Team Rating
# 1        Trent Boult  NZ                        697
# 2     Jasprit Bumrah                     IND    682
# 3     Shaheen Afridi                     PAK    681
# 4     Josh Hazlewood                     AUS    679
# 5   Mujeeb Ur Rahman                     AFG    676
# 6       Mehedi Hasan                     BAN    672
# 7         Matt Henry                      NZ    663
# 8      Mohammad Nabi                     AFG    657
# 9        Rashid Khan                     AFG    651
# 10      Chris Woakes                     ENG    640

# %% [markdown]
# # Q6. Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
#
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
women_cricket=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
women_cricket
# Out:
# <Response [200]>

# %% [markdown]
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#
# Answer :

# %%
soup=BeautifulSoup(women_cricket.content)
team=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    team.append(i.text)
m1=[]
for j in soup.find_all('td',class_="rankings-block__banner--matches"):
    m1.append(j.text)
m2=[]
for k in soup.find_all('td',class_="table-body__cell u-center-text"):
    m2.append(k.text)
del m2[1:39:2]
matches=m1+m2
p1=[]
for l in soup.find_all('td',class_="rankings-block__banner--points"):
    p1.append(l.text)
p2=[]
for m in soup.find_all('td',class_="table-body__cell u-center-text"):
    p2.append(m.text)
del p2[0:39:2]
points=p1+p2
r1=[]
for n in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    r1.append(n.text.replace('\n',''))
r2=[]
for o in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    r2.append(o.text)
rating=r1+r2
import pandas as pd
import numpy as np
df=pd.DataFrame({'Team':team,'Matches':matches,'Points':points,'Rating':rating})
print('Top 10 ODI teams in Women’s cricket :')
df.index = np.arange(1,len(df)+1)
df.head(10)
# Out:
# Top 10 ODI teams in Women’s cricket :
#             Team Matches Points  \
# 1      Australia      29  4,837
# 2        England      33  4,046
# 3   South Africa      35  4,157
# 4          India      32  3,219
# 5    New Zealand      31  3,019
# 6    West Indies      30  2,768
# 7     Bangladesh      12    930
# 8       Pakistan      30  1,962
# 9      Sri Lanka      11    495
# 10       Ireland       8    351
#
#                                                Rating
# 1                               167               ...
# 2                                                 123
# 3                                                 119
# 4                                                 101
# 5                                                  97
# 6                                                  92
# 7                                                  78
# 8                                                  65
# 9                                                  45
# 10                                                 44

# %% [markdown]
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
#
# Answer :

# %%
women_batsmen=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
women_batsmen
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(women_batsmen.content)
p1=[]
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    p1.append(i.text)
p2=[]
for j in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    p2.append(j.text.replace('\n',''))
player=p1+p2
t1=[]
for a in soup.find_all('div',class_="rankings-block__banner--nationality"):
    t1.append(a.text.replace('\n',''))
t2=[]
for b in soup.find_all('span',class_="table-body__logo-text"):
    t2.append(b.text)
team=t1+t2
r1=[]
for n in soup.find_all('div',class_="rankings-block__banner--rating"):
    r1.append(n.text)
r2=[]
for o in soup.find_all('td',class_="table-body__cell rating"):
    r2.append(o.text)
rating=r1+r2
import pandas as pd
import numpy as np
df=pd.DataFrame({'Batting Players':player,'Team':team,'Rating':rating})
print('Top 10 Womens ODI Battting Players :')
df.index = np.arange(1,len(df)+1)
df.head(10)
# Out:
# Top 10 Womens ODI Battting Players :
#         Batting Players                     Team Rating
# 1          Alyssa Healy  AUS                        785
# 2           Beth Mooney                      AUS    749
# 3        Natalie Sciver                      ENG    747
# 4       Laura Wolvaardt                       SA    732
# 5           Meg Lanning                      AUS    710
# 6        Rachael Haynes                      AUS    701
# 7     Amy Satterthwaite                       NZ    681
# 8        Tammy Beaumont                      ENG    667
# 9   Chamari Athapaththu                       SL    655
# 10      Smriti Mandhana                      IND    649

# %% [markdown]
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.
#
# Answer :

# %%
women_allrounder=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
women_allrounder
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(women_allrounder.content)
p1=[]
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    p1.append(i.text)
p2=[]
for j in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    p2.append(j.text.replace('\n',''))
player=p1+p2
t1=[]
for a in soup.find_all('div',class_="rankings-block__banner--nationality"):
    t1.append(a.text.replace('\n',''))
t2=[]
for b in soup.find_all('span',class_="table-body__logo-text"):
    t2.append(b.text)
team=t1+t2
r1=[]
for n in soup.find_all('div',class_="rankings-block__banner--rating"):
    r1.append(n.text)
r2=[]
for o in soup.find_all('td',class_="table-body__cell rating"):
    r2.append(o.text)
rating=r1+r2
import pandas as pd
import numpy as np
df=pd.DataFrame({'All-Rounder':player,'Team':team,'Rating':rating})
print('Top 10 Womens ODI All-Rounder :')
df.index = np.arange(1,len(df)+1)
df.head(10)
# Out:
# Top 10 Womens ODI All-Rounder :
#          All-Rounder                     Team Rating
# 1     Natalie Sciver  ENG                        379
# 2       Ellyse Perry                      AUS    374
# 3     Marizanne Kapp                       SA    349
# 4    Hayley Matthews                       WI    339
# 5        Amelia Kerr                       NZ    336
# 6   Ashleigh Gardner                      AUS    270
# 7      Deepti Sharma                      IND    252
# 8      Jess Jonassen                      AUS    246
# 9    Katherine Brunt                      ENG    220
# 10   Stafanie Taylor                       WI    207

# %% [markdown]
# # Q7. rite a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world :
#
# i) Headline
#
# ii) Time
#
# iii) News Link

# %%
news = requests.get('https://www.cnbc.com/world/?region=world')
news
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(news.content)
headline = []
for i in soup.find_all('a',class_="LatestNews-headline"):
    headline.append(i.text)
time = []
for j in soup.find_all('time',class_="LatestNews-timestamp"):
    time.append(j.text)
news_link = []
for k in soup.find_all('a',class_="LatestNews-headline"):
    news_link.append(k['href'])
import pandas as pd
df = pd.DataFrame({'Headline':headline, 'Time':time, 'News Link': news_link})
df1=df.set_index('Headline')
df1
# Out:
#                                                               Time  \
# Headline
# Hong Kong cuts hotel quarantine for travelers t...     2 Hours Ago
# Baidu's robotaxis don't need any human staff in...     2 Hours Ago
# Cramer: The Inflation Reduction Act is really a...     4 Hours Ago
# Wall Street likes growth stocks again. Here are...     4 Hours Ago
# BlackRock: The era of steady growth has ended, ...     4 Hours Ago
# Video game giants had a miserable second quarte...     4 Hours Ago
# Asia-Pacific markets slip in early trade; SoftB...     5 Hours Ago
# Celsius withdraws motion to hire CFO back at $9...     6 Hours Ago
# Potential curb on Australian LNG exports is ano...     6 Hours Ago
# Stock futures flat following S&P 500's third wi...     7 Hours Ago
# Climate groups react to Senate passing the Infl...     8 Hours Ago
# The best and worst places to live in the world ...    13 Hours Ago
# George Clooney had tequila, Ryan Reynolds gin. ...    15 Hours Ago
# 9 corporate leaders share their best hacks for ...    15 Hours Ago
# Bethenny Frankel: The most successful people ha...    16 Hours Ago
# The 7 states with the least credit card debt          16 Hours Ago
# Albemarle beats estimates on lithium prices, CE...    17 Hours Ago
# These stocks are best positioned to weather a l...    17 Hours Ago
# Strong returns are hard to find in 2022. Three ...    17 Hours Ago
# Some consumers are cutting back on restaurant s...    17 Hours Ago
# Climate change is making some homes to costly t...    17 Hours Ago
# Why creating a horror movie haven on Netflix ma...    18 Hours Ago
# Elon Musk challenges Twitter CEO Parag Agrawal ...  August 6, 2022
# Large Indiana employers Eli Lilly and Cummins s...  August 6, 2022
# Czech prince raises $300,000 in NFTs to restore...  August 6, 2022
# President Joe Biden tests negative for Covid-19...  August 6, 2022
# Fed Governor Bowman sees 'similarly sized' inte...  August 6, 2022
# This 39-year-old makes $160K/month in passive i...  August 6, 2022
# Most of Buffett’s portfolio is tied up in just ...  August 6, 2022
# 5 tips for cutting down on credit card costs ah...  August 6, 2022
#
#                                                                                             News Link
# Headline
# Hong Kong cuts hotel quarantine for travelers t...  https://www.cnbc.com/2022/08/08/hong-kong-redu...
# Baidu's robotaxis don't need any human staff in...  https://www.cnbc.com/2022/08/08/baidus-robotax...
# Cramer: The Inflation Reduction Act is really a...  https://www.cnbc.com/2022/08/07/cramer-the-inf...
# Wall Street likes growth stocks again. Here are...  https://www.cnbc.com/2022/08/08/wall-street-ba...
# BlackRock: The era of steady growth has ended, ...  https://www.cnbc.com/2022/08/08/blackrock-era-...
# Video game giants had a miserable second quarte...  https://www.cnbc.com/2022/08/08/microsoft-xbox...
# Asia-Pacific markets slip in early trade; SoftB...  https://www.cnbc.com/2022/08/08/asia-markets-c...
# Celsius withdraws motion to hire CFO back at $9...  https://www.cnbc.com/2022/08/07/celsius-withdr...
# Potential curb on Australian LNG exports is ano...  https://www.cnbc.com/2022/08/07/potential-curb...
# Stock futures flat following S&P 500's third wi...  https://www.cnbc.com/2022/08/07/stock-market-n...
# Climate groups react to Senate passing the Infl...  https://www.cnbc.com/2022/08/07/climate-groups...
# The best and worst places to live in the world ...  https://www.cnbc.com/2022/08/07/global-liveabi...
# George Clooney had tequila, Ryan Reynolds gin. ...  https://www.cnbc.com/2022/08/07/george-clooney...
# 9 corporate leaders share their best hacks for ...  https://www.cnbc.com/2022/08/07/9-busy-people-...
# Bethenny Frankel: The most successful people ha...  https://www.cnbc.com/2022/08/07/bethenny-frank...
# The 7 states with the least credit card debt        https://www.cnbc.com/2022/08/07/states-with-th...
# Albemarle beats estimates on lithium prices, CE...  https://www.cnbc.com/2022/08/07/lithium-is-key...
# These stocks are best positioned to weather a l...  https://www.cnbc.com/2022/08/07/these-stocks-a...
# Strong returns are hard to find in 2022. Three ...  https://www.cnbc.com/2022/08/07/strong-returns...
# Some consumers are cutting back on restaurant s...  https://www.cnbc.com/2022/08/07/consumers-are-...
# Climate change is making some homes to costly t...  https://www.cnbc.com/2022/08/07/climate-change...
# Why creating a horror movie haven on Netflix ma...  https://www.cnbc.com/2022/08/07/netflix-may-be...
# Elon Musk challenges Twitter CEO Parag Agrawal ...  https://www.cnbc.com/2022/08/06/elon-musk-chal...
# Large Indiana employers Eli Lilly and Cummins s...  https://www.cnbc.com/2022/08/06/eli-lilly-says...
# Czech prince raises $300,000 in NFTs to restore...  https://www.cnbc.com/2022/08/06/27-year-old-bo...
# President Joe Biden tests negative for Covid-19...  https://www.cnbc.com/2022/08/06/president-joe-...
# Fed Governor Bowman sees 'similarly sized' inte...  https://www.cnbc.com/2022/08/06/fed-governor-b...
# This 39-year-old makes $160K/month in passive i...  https://www.cnbc.com/2022/08/06/this-39-year-o...
# Most of Buffett’s portfolio is tied up in just ...  https://www.cnbc.com/2022/08/06/most-of-warren...
# 5 tips for cutting down on credit card costs ah...  https://www.cnbc.com/2022/08/06/how-to-curb-cr...

# %% [markdown]
# # Q8. Write a python program to scrape the details of most downloaded articles from AI in last 90 days. https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles Scrape below mentioned details :
#
# i) Paper Title
#
# ii) Authors
#
# iii) Published Date
#
# iv) Paper URL

# %%
page = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
soup=BeautifulSoup(page.content)
title = []
for i in soup.find_all('h2',class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR"):
    title.append(i.text)
author = []
for j in soup.find_all('span',class_="sc-1w3fpd7-0 pgLAT"):
    author.append(j.text)
pub_date = []
for k in soup.find_all('span',class_="sc-1thf9ly-2 bKddwo"):
    pub_date.append(k.text)
paper_url = []
for l in soup.find_all('a',class_="sc-5smygv-0 nrDZj"):
    paper_url.append(l['href'])
import pandas as pd
df1=pd.DataFrame({'Paper Title':title, 'Authors':author, 'Published Date':pub_date, 'Paper URL':paper_url})
df=df1.set_index('Paper Title')
df
# Out:
#                                                                                               Authors  \
# Paper Title
# Reward is enough                                    Silver, David, Singh, Satinder, Precup, Doina,...
# Making sense of raw input                                   Evans, Richard, Bošnjak, Matko and 5 more
# Law and logic: A review from an argumentation p...                  Prakken, Henry, Sartor, Giovanni
# Creativity and artificial intelligence                                            Boden, Margaret A.
# Artificial cognition for social human–robot int...    Lemaignan, Séverin, Warnier, Mathieu and 3 more
# Explanation in artificial intelligence: Insight...                                       Miller, Tim
# Making sense of sensory input                       Evans, Richard, Hernández-Orallo, José and 3 more
# Conflict-based search for optimal multi-agent p...  Sharon, Guni, Stern, Roni, Felner, Ariel, Stur...
# Between MDPs and semi-MDPs: A framework for tem...  Sutton, Richard S., Precup, Doina, Singh, Sati...
# The Hanabi challenge: A new frontier for AI res...        Bard, Nolan, Foerster, Jakob N. and 13 more
# Evaluating XAI: A comparison of rule-based and ...  van der Waa, Jasper, Nieuwburg, Elisabeth, Cre...
# Argumentation in artificial intelligence                         Bench-Capon, T.J.M., Dunne, Paul E.
# Algorithms for computing strategies in two-play...       Bošanský, Branislav, Lisý, Viliam and 3 more
# Multiple object tracking: A literature review                  Luo, Wenhan, Xing, Junliang and 4 more
# Selection of relevant features and examples in ...                      Blum, Avrim L., Langley, Pat
# A survey of inverse reinforcement learning: Cha...                   Arora, Saurabh, Doshi, Prashant
# Explaining individual predictions when features...      Aas, Kjersti, Jullum, Martin, Løland, Anders
# A review of possible effects of cognitive biase...  Kliegr, Tomáš, Bahník, Štěpán, Fürnkranz, Joha...
# Integrating social power into the decision-maki...    Pereira, Gonçalo, Prada, Rui, Santos, Pedro A.
# “That's (not) the output I expected!” On the ro...                      Riveiro, Maria, Thill, Serge
# Explaining black-box classifiers using post-hoc...  Kenny, Eoin M., Ford, Courtney, Quinn, Molly, ...
# Algorithm runtime prediction: Methods & evaluation  Hutter, Frank, Xu, Lin, Hoos, Holger H., Leyto...
# Wrappers for feature subset selection                                   Kohavi, Ron, John, George H.
# Commonsense visual sensemaking for autonomous d...  Suchan, Jakob, Bhatt, Mehul, Varadarajan, Srik...
# Quantum computation, quantum theory and AI                                           Ying, Mingsheng
#
#                                                     Published Date  \
# Paper Title
# Reward is enough                                      October 2021
# Making sense of raw input                             October 2021
# Law and logic: A review from an argumentation p...    October 2015
# Creativity and artificial intelligence                 August 1998
# Artificial cognition for social human–robot int...       June 2017
# Explanation in artificial intelligence: Insight...   February 2019
# Making sense of sensory input                           April 2021
# Conflict-based search for optimal multi-agent p...   February 2015
# Between MDPs and semi-MDPs: A framework for tem...     August 1999
# The Hanabi challenge: A new frontier for AI res...      March 2020
# Evaluating XAI: A comparison of rule-based and ...   February 2021
# Argumentation in artificial intelligence              October 2007
# Algorithms for computing strategies in two-play...     August 2016
# Multiple object tracking: A literature review           April 2021
# Selection of relevant features and examples in ...   December 1997
# A survey of inverse reinforcement learning: Cha...     August 2021
# Explaining individual predictions when features...  September 2021
# A review of possible effects of cognitive biase...       June 2021
# Integrating social power into the decision-maki...   December 2016
# “That's (not) the output I expected!” On the ro...  September 2021
# Explaining black-box classifiers using post-hoc...        May 2021
# Algorithm runtime prediction: Methods & evaluation    January 2014
# Wrappers for feature subset selection                December 1997
# Commonsense visual sensemaking for autonomous d...    October 2021
# Quantum computation, quantum theory and AI           February 2010
#
#                                                                                             Paper URL
# Paper Title
# Reward is enough                                    https://www.sciencedirect.com/science/article/...
# Making sense of raw input                           https://www.sciencedirect.com/science/article/...
# Law and logic: A review from an argumentation p...  https://www.sciencedirect.com/science/article/...
# Creativity and artificial intelligence              https://www.sciencedirect.com/science/article/...
# Artificial cognition for social human–robot int...  https://www.sciencedirect.com/science/article/...
# Explanation in artificial intelligence: Insight...  https://www.sciencedirect.com/science/article/...
# Making sense of sensory input                       https://www.sciencedirect.com/science/article/...
# Conflict-based search for optimal multi-agent p...  https://www.sciencedirect.com/science/article/...
# Between MDPs and semi-MDPs: A framework for tem...  https://www.sciencedirect.com/science/article/...
# The Hanabi challenge: A new frontier for AI res...  https://www.sciencedirect.com/science/article/...
# Evaluating XAI: A comparison of rule-based and ...  https://www.sciencedirect.com/science/article/...
# Argumentation in artificial intelligence            https://www.sciencedirect.com/science/article/...
# Algorithms for computing strategies in two-play...  https://www.sciencedirect.com/science/article/...
# Multiple object tracking: A literature review       https://www.sciencedirect.com/science/article/...
# Selection of relevant features and examples in ...  https://www.sciencedirect.com/science/article/...
# A survey of inverse reinforcement learning: Cha...  https://www.sciencedirect.com/science/article/...
# Explaining individual predictions when features...  https://www.sciencedirect.com/science/article/...
# A review of possible effects of cognitive biase...  https://www.sciencedirect.com/science/article/...
# Integrating social power into the decision-maki...  https://www.sciencedirect.com/science/article/...
# “That's (not) the output I expected!” On the ro...  https://www.sciencedirect.com/science/article/...
# Explaining black-box classifiers using post-hoc...  https://www.sciencedirect.com/science/article/...
# Algorithm runtime prediction: Methods & evaluation  https://www.sciencedirect.com/science/article/...
# Wrappers for feature subset selection               https://www.sciencedirect.com/science/article/...
# Commonsense visual sensemaking for autonomous d...  https://www.sciencedirect.com/science/article/...
# Quantum computation, quantum theory and AI          https://www.sciencedirect.com/science/article/...

# %% [markdown]
# # Q9. Write a python program to scrape mentioned details from dineout.co.in :
#
# i) Restaurant name
#
# ii) Cuisine
#
# iii) Location
#
# iv) Ratings
#
# v) Image URL

# %% [markdown]
# Answer :

# %%
dine = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
dine
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(dine.content)
rest_name = []
for i in soup.find_all('div',class_="restnt-info cursor"):
    for j in i.find_all('a',class_="restnt-name ellipsis"):
        rest_name.append(j.text)
cui = []
for l in soup.find_all('div',class_="detail-info"):
    cui.append(l.text)
loc = []
for k in soup.find_all('div',class_="restnt-loc ellipsis"):
    loc.append(k.text)
rating = []
for m in soup.find_all('div',class_="restnt-rating rating-4"):
    rating.append(m.text)
image_url = []
for n in soup.find_all('img',class_="no-img"):
    image_url.append(n['data-src'])
import pandas
df =pandas.DataFrame({'Restaurant Name':rest_name, 'Cuisine':cui, 'Location':loc, 'Ratings':rating, 'Image URL':image_url})
df1=df.set_index('Restaurant Name')
df1
# Out:
#                                                                             Cuisine  \
# Restaurant Name
# Castle Barbeque                      ₹ 2,000 for 2 (approx) | Chinese, North Indian
# Jungle Jamboree                   ₹ 1,680 for 2 (approx) | North Indian, Asian, ...
# Cafe Knosh                            ₹ 3,000 for 2 (approx) | Italian, Continental
# Castle Barbeque                      ₹ 2,000 for 2 (approx) | Chinese, North Indian
# The Barbeque Company              ₹ 1,700 for 2 (approx) | North Indian, Chinese...
# India Grill                          ₹ 2,400 for 2 (approx) | North Indian, Italian
# Delhi Barbeque                                ₹ 1,800 for 2 (approx) | North Indian
# The Monarch - Bar Be Que Village              ₹ 1,900 for 2 (approx) | North Indian
# Indian Grill Room                    ₹ 2,200 for 2 (approx) | North Indian, Mughlai
#
#                                                                            Location  \
# Restaurant Name
# Castle Barbeque                                      Connaught Place, Central Delhi
# Jungle Jamboree                              3CS Mall,Lajpat Nagar - 3, South Delhi
# Cafe Knosh                        The Leela Ambience Convention Hotel,Shahdara, ...
# Castle Barbeque                              Pacific Mall,Tagore Garden, West Delhi
# The Barbeque Company                             Gardens Galleria,Sector 38A, Noida
# India Grill                                    Hilton Garden Inn,Saket, South Delhi
# Delhi Barbeque                       Taurus Sarovar Portico,Mahipalpur, South Delhi
# The Monarch - Bar Be Que Village  Indirapuram Habitat Centre,Indirapuram, Ghaziabad
# Indian Grill Room                  Suncity Business Tower,Golf Course Road, Gurgaon
#
#                                  Ratings  \
# Restaurant Name
# Castle Barbeque                      4.1
# Jungle Jamboree                      3.9
# Cafe Knosh                           4.3
# Castle Barbeque                      3.9
# The Barbeque Company                   4
# India Grill                          3.9
# Delhi Barbeque                       3.7
# The Monarch - Bar Be Que Village     3.8
# Indian Grill Room                    4.3
#
#                                                                           Image URL
# Restaurant Name
# Castle Barbeque                   https://im1.dineout.co.in/images/uploads/resta...
# Jungle Jamboree                   https://im1.dineout.co.in/images/uploads/resta...
# Cafe Knosh                        https://im1.dineout.co.in/images/uploads/resta...
# Castle Barbeque                   https://im1.dineout.co.in/images/uploads/resta...
# The Barbeque Company              https://im1.dineout.co.in/images/uploads/resta...
# India Grill                       https://im1.dineout.co.in/images/uploads/resta...
# Delhi Barbeque                    https://im1.dineout.co.in/images/uploads/resta...
# The Monarch - Bar Be Que Village  https://im1.dineout.co.in/images/uploads/resta...
# Indian Grill Room                 https://im1.dineout.co.in/images/uploads/resta...

# %% [markdown]
# # Q10. Write a python program to scrape the details of top publications from Google Scholar from https://scholar.google.com/citations?view_op=top_venues&hl=en
#
# i) Rank
#
#
# ii) Publication
#
# iii) h5-index
#
# iv) h5-median

# %% [markdown]
# Answer :

# %%
page=requests.get('https://scholar.google.com/citations?view_op=top_venues&hl=en')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
rank=[]
for i in soup.find_all('td',class_="gsc_mvt_p"):
    rank.append(i.text)
pub=[]
for i in soup.find_all('td',class_="gsc_mvt_t"):
    pub.append(i.text)
h5_index = []
for k in soup.find_all('a',class_="gs_ibl gsc_mp_anchor"):
    h5_index.append(k.text)
h5m = []
for l in soup.find_all('span',class_="gs_ibl gsc_mp_anchor"):
    h5m.append(l.text)
import pandas as pan
df = pan.DataFrame({'Rank':rank, 'Publication':pub, 'h5-index':h5_index, 'h5-median':h5m})
df1=df.set_index('Rank')
df1
# Out:
#                                             Publication h5-index h5-median
# Rank
# 1.                                               Nature      444       667
# 2.                  The New England Journal of Medicine      432       780
# 3.                                              Science      401       614
# 4.    IEEE/CVF Conference on Computer Vision and Pat...      389       627
# 5.                                           The Lancet      354       635
# ...                                                 ...      ...       ...
# 96.                        Journal of Business Research      145       233
# 97.                                    Molecular Cancer      145       209
# 98.                                             Sensors      145       201
# 99.                               Nature Climate Change      144       228
# 100.                    IEEE Internet of Things Journal      144       212
#
# [100 rows x 3 columns]
